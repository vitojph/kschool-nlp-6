# %% [markdown]
# # `spacy`: el *Ruby on Rails* del PLN
#
# [spacy](http://www.spacy.io/) es una librería de procesamiento del lenguaje natural, robusta, rápida, fácil de instalar y utilizar e integrable con [otras librerías de *NLP* y de *deep learning*](https://spacy.io/usage/facts-figures#section-other-libraries).
#
# Tiene modelos entrenados en varios idiomas y permite realizar las [típicas tareas](https://spacy.io/usage/facts-figures) de segmentación por oraciones, tokenizanción, análisis morfológico, extracción de entidades y análisis de opinión.
#
# Veamos cómo funciona. Lo primero es instalar algunos modelos, en inglés y español. Desde la línea de comandos, ejecuta:

# %%
# !python3 -m spacy download en
# !python3 -m spacy download es

# %% [markdown]
# Una vez instalados los modelos, podemos importarlos fácilmente:

# %%
import spacy

# cargamos el modelo entrenado en español
nlp = spacy.load('es')

texto = '''España incumple la regla del déficit del euro y queda como único país bajo el control de Bruselas. 
España no aprobará finalmente la regla europa del déficit y se quedará como único país de la Eurozona que 
suspende y sigue bajo vigilancia. El Gobierno se salta finalmente el requisito de saneamiento presupuestario 
del Tratado de Maastricht y obtiene así más margen de gasto en 2018.'''

# y procesamos el texto
doc = nlp(texto)

# %% [markdown]
# ## Procesando oraciones, palabras y entidades
#
# Podemos iterar fácilmente sobre la lista de oraciones y recorrer los tokens para acceder a su información morfo-sintáctica:

# %%
for sentence in doc.sents:
    print('Oración: {}'.format(sentence))
    for token in sentence:
        print("{} con lema '{}', tiene la categoría gramatical {}/{} y la dependencia {}".format(token, token.lemma_, token.pos_, token.tag_, token.dep_))
# Out:
# Oración: España incumple la regla del déficit del euro y queda como único país bajo el control de Bruselas.
#
# España con lema 'España', tiene la categoría gramatical PROPN/PROPN___ y la dependencia nsubj
# incumple con lema 'incumplir', tiene la categoría gramatical VERB/VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin y la dependencia ROOT
# la con lema 'lo', tiene la categoría gramatical DET/DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art y la dependencia det
# regla con lema 'reglar', tiene la categoría gramatical NOUN/NOUN__Gender=Fem|Number=Sing y la dependencia obj
# del con lema 'del', tiene la categoría gramatical ADP/ADP__AdpType=Preppron|Gender=Masc|Number=Sing y la dependencia case
# déficit con lema 'déficit', tiene la categoría gramatical NOUN/NOUN__Gender=Masc|Number=Sing y la dependencia nmod
# del con lema 'del', tiene la categoría gramatical ADP/ADP__AdpType=Preppron|Gender=Masc|Number=Sing y la dependencia case
# euro con lema 'euro', tiene la categoría gramatical NOUN/NOUN__Gender=Masc|Number=Sing y la dependencia nmod
# y con lema 'y', tiene la categoría gramatical CONJ/CCONJ___ y la dependencia cc
# queda con lema 'quedo', tiene la categoría gramatical VERB/VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin y la dependencia conj
# como con lema 'comer', tiene la categoría gramatical SCONJ/SCONJ___ y la dependencia mark
# único con lema 'único', tiene la categoría gramatical ADJ/ADJ__Gender=Masc|Number=Sing y la dependencia amod
# país con lema 'país', tiene la categoría gramatical NOUN/NOUN__Gender=Masc|Number=Sing y la dependencia obj
# bajo con lema 'bajar', tiene la categoría gramatical ADP/ADP__AdpType=Prep y la dependencia case
# el con lema 'el', tiene la categoría gramatical DET/DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art y la dependencia det
# control con lema 'control', tiene la categoría gramatical NOUN/NOUN__Gender=Masc|Number=Sing y la dependencia obl
# de con lema 'de', tiene la categoría gramatical ADP/ADP__AdpType=Prep y la dependencia case
# Bruselas con lema 'Bruselas', tiene la categoría gramatical PROPN/PROPN___ y la dependencia nmod
# . con lema '.', tiene la categoría gramatical PUNCT/PUNCT__PunctType=Peri y la dependencia punct
#
#  con lema '
# ', tiene la categoría gramatical SPACE/ y la dependencia
# Oración: España no aprobará finalmente la regla europa del déficit y se quedará como único país de la Eurozona que
# suspende y sigue bajo vigilancia.
# España con lema 'España', tiene la categoría gramatical PROPN/PROPN___ y la dependencia nsubj
# no con lema 'no', tiene la categoría gramatical ADV/ADV__Polarity=Neg y la dependencia advmod
# aprobará con lema 'aprobar', tiene la categoría gramatical VERB/VERB__Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin y la dependencia ROOT
# finalmente con lema 'finalmente', tiene la categoría gramatical ADV/ADV___ y la dependencia advmod
# la con lema 'lo', tiene la categoría gramatical DET/DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art y la dependencia det
# regla con lema 'reglar', tiene la categoría gramatical NOUN/NOUN__Gender=Fem|Number=Sing y la dependencia obj
# europa con lema 'europa', tiene la categoría gramatical NOUN/NOUN__Gender=Fem|Number=Sing y la dependencia amod
# del con lema 'del', tiene la categoría gramatical ADP/ADP__AdpType=Preppron|Gender=Masc|Number=Sing y la dependencia case
# déficit con lema 'déficit', tiene la categoría gramatical NOUN/NOUN__Gender=Masc|Number=Sing y la dependencia nmod
# y con lema 'y', tiene la categoría gramatical CONJ/CCONJ___ y la dependencia cc
# se con lema 'se', tiene la categoría gramatical PRON/PRON__Person=3 y la dependencia obj
# quedará con lema 'quedar', tiene la categoría gramatical VERB/VERB__Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin y la dependencia conj
# como con lema 'comer', tiene la categoría gramatical SCONJ/SCONJ___ y la dependencia mark
# único con lema 'único', tiene la categoría gramatical ADJ/ADJ__Gender=Masc|Number=Sing y la dependencia amod
# país con lema 'país', tiene la categoría gramatical NOUN/NOUN__Gender=Masc|Number=Sing y la dependencia obl
# de con lema 'de', tiene la categoría gramatical ADP/ADP__AdpType=Prep y la dependencia case
# la con lema 'lo', tiene la categoría gramatical DET/DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art y la dependencia det
# Eurozona con lema 'Eurozona', tiene la categoría gramatical PROPN/PROPN___ y la dependencia nmod
# que con lema 'que', tiene la categoría gramatical PRON/PRON__PronType=Rel y la dependencia nsubj
#
#  con lema '
# ', tiene la categoría gramatical SPACE/ y la dependencia
# suspende con lema 'suspender', tiene la categoría gramatical VERB/VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin y la dependencia acl
# y con lema 'y', tiene la categoría gramatical CONJ/CCONJ___ y la dependencia cc
# sigue con lema 'seguir', tiene la categoría gramatical VERB/VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin y la dependencia conj
# bajo con lema 'bajar', tiene la categoría gramatical ADP/ADP__AdpType=Prep y la dependencia case
# vigilancia con lema 'vigilancia', tiene la categoría gramatical NOUN/NOUN__Gender=Fem|Number=Sing y la dependencia obl
# . con lema '.', tiene la categoría gramatical PUNCT/PUNCT__PunctType=Peri y la dependencia punct
# Oración: El Gobierno se salta finalmente el requisito de saneamiento presupuestario
# del Tratado de Maastricht y obtiene así más margen de gasto en 2018.
# El con lema 'El', tiene la categoría gramatical DET/DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art y la dependencia det
# Gobierno con lema 'Gobierno', tiene la categoría gramatical PROPN/PROPN___ y la dependencia nsubj
# se con lema 'se', tiene la categoría gramatical PRON/PRON__Person=3 y la dependencia obj
# salta con lema 'saltar', tiene la categoría gramatical VERB/VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin y la dependencia ROOT
# finalmente con lema 'finalmente', tiene la categoría gramatical ADV/ADV___ y la dependencia advmod
# el con lema 'el', tiene la categoría gramatical DET/DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art y la dependencia det
# requisito con lema 'requerir', tiene la categoría gramatical NOUN/NOUN__Gender=Masc|Number=Sing y la dependencia obj
# de con lema 'de', tiene la categoría gramatical ADP/ADP__AdpType=Prep y la dependencia case
# saneamiento con lema 'saneamiento', tiene la categoría gramatical NOUN/NOUN__Gender=Masc|Number=Sing y la dependencia nmod
# presupuestario con lema 'presupuestario', tiene la categoría gramatical ADJ/ADJ__Gender=Masc|Number=Sing y la dependencia amod
#
#  con lema '
# ', tiene la categoría gramatical SPACE/ y la dependencia
# del con lema 'del', tiene la categoría gramatical ADP/ADP__AdpType=Preppron|Gender=Masc|Number=Sing y la dependencia case
# Tratado con lema 'Tratado', tiene la categoría gramatical PROPN/PROPN___ y la dependencia nmod
# de con lema 'de', tiene la categoría gramatical ADP/ADP__AdpType=Prep y la dependencia case
# Maastricht con lema 'Maastricht', tiene la categoría gramatical PROPN/PROPN___ y la dependencia flat
# y con lema 'y', tiene la categoría gramatical CONJ/CCONJ___ y la dependencia cc
# obtiene con lema 'obtener', tiene la categoría gramatical VERB/VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin y la dependencia conj
# así con lema 'asir', tiene la categoría gramatical ADV/ADV___ y la dependencia advmod
# más con lema 'más', tiene la categoría gramatical ADV/ADV___ y la dependencia advmod
# margen con lema 'margen', tiene la categoría gramatical NOUN/NOUN__Number=Sing y la dependencia obj
# de con lema 'de', tiene la categoría gramatical ADP/ADP__AdpType=Prep y la dependencia case
# gasto con lema 'gastar', tiene la categoría gramatical NOUN/NOUN__Gender=Masc|Number=Sing y la dependencia nmod
# en con lema 'en', tiene la categoría gramatical ADP/ADP__AdpType=Prep y la dependencia case
# 2018 con lema '2018', tiene la categoría gramatical NOUN/NOUN__AdvType=Tim y la dependencia obl
# . con lema '.', tiene la categoría gramatical PUNCT/PUNCT__PunctType=Peri y la dependencia punct

# %% [markdown]
# El elemeno `doc` tiene una propiedad `.ents` que permite acceder a las entidades nombradas que hayan sido localizadas:

# %%
print(doc.ents)

for entity in doc.ents:
    print('{} es de tipo {}'.format(entity, entity.label_))
# Out:
# (España, Bruselas,
# , España, Eurozona,
# , El Gobierno,
# , Tratado de Maastricht)
# España es de tipo PER
# Bruselas es de tipo LOC
#
#  es de tipo ORG
# España es de tipo LOC
# Eurozona es de tipo LOC
#
#  es de tipo ORG
# El Gobierno es de tipo MISC
#
#  es de tipo ORG
# Tratado de Maastricht es de tipo MISC

# %% [markdown]
# ## Visualizando árboles de dependencias y entidades
#
# Podemos acceder al árbol completo a través del método `.print_tree()`:

# %%
doc.print_tree()
# Out:
# /usr/lib/python3.6/runpy.py:193: DeprecationWarning: Positional arguments to Doc.merge are deprecated. Instead, use the keyword arguments, for example tag=, lemma= or ent_type=.
#   "__main__", mod_spec)
# /usr/lib/python3.6/runpy.py:193: DeprecationWarning: Positional arguments to Doc.merge are deprecated. Instead, use the keyword arguments, for example tag=, lemma= or ent_type=.
#   "__main__", mod_spec)
# /usr/lib/python3.6/runpy.py:193: DeprecationWarning: Positional arguments to Doc.merge are deprecated. Instead, use the keyword arguments, for example tag=, lemma= or ent_type=.
#   "__main__", mod_spec)
# /usr/lib/python3.6/runpy.py:193: DeprecationWarning: Positional arguments to Doc.merge are deprecated. Instead, use the keyword arguments, for example tag=, lemma= or ent_type=.
#   "__main__", mod_spec)
# /usr/lib/python3.6/runpy.py:193: DeprecationWarning: Positional arguments to Doc.merge are deprecated. Instead, use the keyword arguments, for example tag=, lemma= or ent_type=.
#   "__main__", mod_spec)
# /usr/lib/python3.6/runpy.py:193: DeprecationWarning: Positional arguments to Doc.merge are deprecated. Instead, use the keyword arguments, for example tag=, lemma= or ent_type=.
#   "__main__", mod_spec)
# /usr/lib/python3.6/runpy.py:193: DeprecationWarning: Positional arguments to Doc.merge are deprecated. Instead, use the keyword arguments, for example tag=, lemma= or ent_type=.
#   "__main__", mod_spec)
# /usr/lib/python3.6/runpy.py:193: DeprecationWarning: Positional arguments to Doc.merge are deprecated. Instead, use the keyword arguments, for example tag=, lemma= or ent_type=.
#   "__main__", mod_spec)
# /usr/lib/python3.6/runpy.py:193: DeprecationWarning: Positional arguments to Doc.merge are deprecated. Instead, use the keyword arguments, for example tag=, lemma= or ent_type=.
#   "__main__", mod_spec)
# [{'NE': '',
#   'POS_coarse': 'VERB',
#   'POS_fine': 'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#   'arc': 'ROOT',
#   'lemma': 'incumplir',
#   'modifiers': [{'NE': 'PER',
#     'POS_coarse': 'PROPN',
#     'POS_fine': 'PROPN___',
#     'arc': 'nsubj',
#     'lemma': 'España',
#     'modifiers': [],
#     'word': 'España'},
#    {'NE': '',
#     'POS_coarse': 'NOUN',
#     'POS_fine': 'NOUN__Gender=Fem|Number=Sing',
#     'arc': 'obj',
#     'lemma': 'reglar',
#     'modifiers': [{'NE': '',
#       'POS_coarse': 'DET',
#       'POS_fine': 'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#       'arc': 'det',
#       'lemma': 'lo',
#       'modifiers': [],
#       'word': 'la'},
#      {'NE': '',
#       'POS_coarse': 'NOUN',
#       'POS_fine': 'NOUN__Gender=Masc|Number=Sing',
#       'arc': 'nmod',
#       'lemma': 'déficit',
#       'modifiers': [{'NE': '',
#         'POS_coarse': 'ADP',
#         'POS_fine': 'ADP__AdpType=Preppron|Gender=Masc|Number=Sing',
#         'arc': 'case',
#         'lemma': 'del',
#         'modifiers': [],
#         'word': 'del'},
#        {'NE': '',
#         'POS_coarse': 'NOUN',
#         'POS_fine': 'NOUN__Gender=Masc|Number=Sing',
#         'arc': 'nmod',
#         'lemma': 'euro',
#         'modifiers': [{'NE': '',
#           'POS_coarse': 'ADP',
#           'POS_fine': 'ADP__AdpType=Preppron|Gender=Masc|Number=Sing',
#           'arc': 'case',
#           'lemma': 'del',
#           'modifiers': [],
#           'word': 'del'}],
#         'word': 'euro'}],
#       'word': 'déficit'}],
#     'word': 'regla'},
#    {'NE': '',
#     'POS_coarse': 'VERB',
#     'POS_fine': 'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#     'arc': 'conj',
#     'lemma': 'quedo',
#     'modifiers': [{'NE': '',
#       'POS_coarse': 'CONJ',
#       'POS_fine': 'CCONJ___',
#       'arc': 'cc',
#       'lemma': 'y',
#       'modifiers': [],
#       'word': 'y'},
#      {'NE': '',
#       'POS_coarse': 'NOUN',
#       'POS_fine': 'NOUN__Gender=Masc|Number=Sing',
#       'arc': 'obj',
#       'lemma': 'país',
#       'modifiers': [{'NE': '',
#         'POS_coarse': 'SCONJ',
#         'POS_fine': 'SCONJ___',
#         'arc': 'mark',
#         'lemma': 'comer',
#         'modifiers': [],
#         'word': 'como'},
#        {'NE': '',
#         'POS_coarse': 'ADJ',
#         'POS_fine': 'ADJ__Gender=Masc|Number=Sing',
#         'arc': 'amod',
#         'lemma': 'único',
#         'modifiers': [],
#         'word': 'único'}],
#       'word': 'país'},
#      {'NE': '',
#       'POS_coarse': 'NOUN',
#       'POS_fine': 'NOUN__Gender=Masc|Number=Sing',
#       'arc': 'obl',
#       'lemma': 'control',
#       'modifiers': [{'NE': '',
#         'POS_coarse': 'ADP',
#         'POS_fine': 'ADP__AdpType=Prep',
#         'arc': 'case',
#         'lemma': 'bajar',
#         'modifiers': [],
#         'word': 'bajo'},
#        {'NE': '',
#         'POS_coarse': 'DET',
#         'POS_fine': 'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#         'arc': 'det',
#         'lemma': 'el',
#         'modifiers': [],
#         'word': 'el'},
#        {'NE': 'LOC',
#         'POS_coarse': 'PROPN',
#         'POS_fine': 'PROPN___',
#         'arc': 'nmod',
#         'lemma': 'Bruselas',
#         'modifiers': [{'NE': '',
#           'POS_coarse': 'ADP',
#           'POS_fine': 'ADP__AdpType=Prep',
#           'arc': 'case',
#           'lemma': 'de',
#           'modifiers': [],
#           'word': 'de'}],
#         'word': 'Bruselas'}],
#       'word': 'control'}],
#     'word': 'queda'},
#    {'NE': '',
#     'POS_coarse': 'PUNCT',
#     'POS_fine': 'PUNCT__PunctType=Peri',
#     'arc': 'punct',
#     'lemma': '.',
#     'modifiers': [{'NE': 'ORG',
#       'POS_coarse': '',
#       'POS_fine': '',
#       'arc': '',
#       'lemma': '\n',
#       'modifiers': [],
#       'word': '\n'}],
#     'word': '.'}],
#   'word': 'incumple'},
#  {'NE': '',
#   'POS_coarse': 'VERB',
#   'POS_fine': 'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin',
#   'arc': 'ROOT',
#   'lemma': 'aprobar',
#   'modifiers': [{'NE': 'LOC',
#     'POS_coarse': 'PROPN',
#     'POS_fine': 'PROPN___',
#     'arc': 'nsubj',
#     'lemma': 'España',
#     'modifiers': [],
#     'word': 'España'},
#    {'NE': '',
#     'POS_coarse': 'ADV',
#     'POS_fine': 'ADV__Polarity=Neg',
#     'arc': 'advmod',
#     'lemma': 'no',
#     'modifiers': [],
#     'word': 'no'},
#    {'NE': '',
#     'POS_coarse': 'ADV',
#     'POS_fine': 'ADV___',
#     'arc': 'advmod',
#     'lemma': 'finalmente',
#     'modifiers': [],
#     'word': 'finalmente'},
#    {'NE': '',
#     'POS_coarse': 'NOUN',
#     'POS_fine': 'NOUN__Gender=Fem|Number=Sing',
#     'arc': 'obj',
#     'lemma': 'reglar',
#     'modifiers': [{'NE': '',
#       'POS_coarse': 'DET',
#       'POS_fine': 'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#       'arc': 'det',
#       'lemma': 'lo',
#       'modifiers': [],
#       'word': 'la'},
#      {'NE': '',
#       'POS_coarse': 'NOUN',
#       'POS_fine': 'NOUN__Gender=Fem|Number=Sing',
#       'arc': 'amod',
#       'lemma': 'europa',
#       'modifiers': [],
#       'word': 'europa'},
#      {'NE': '',
#       'POS_coarse': 'NOUN',
#       'POS_fine': 'NOUN__Gender=Masc|Number=Sing',
#       'arc': 'nmod',
#       'lemma': 'déficit',
#       'modifiers': [{'NE': '',
#         'POS_coarse': 'ADP',
#         'POS_fine': 'ADP__AdpType=Preppron|Gender=Masc|Number=Sing',
#         'arc': 'case',
#         'lemma': 'del',
#         'modifiers': [],
#         'word': 'del'}],
#       'word': 'déficit'}],
#     'word': 'regla'},
#    {'NE': '',
#     'POS_coarse': 'VERB',
#     'POS_fine': 'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin',
#     'arc': 'conj',
#     'lemma': 'quedar',
#     'modifiers': [{'NE': '',
#       'POS_coarse': 'CONJ',
#       'POS_fine': 'CCONJ___',
#       'arc': 'cc',
#       'lemma': 'y',
#       'modifiers': [],
#       'word': 'y'},
#      {'NE': '',
#       'POS_coarse': 'PRON',
#       'POS_fine': 'PRON__Person=3',
#       'arc': 'obj',
#       'lemma': 'se',
#       'modifiers': [],
#       'word': 'se'},
#      {'NE': '',
#       'POS_coarse': 'NOUN',
#       'POS_fine': 'NOUN__Gender=Masc|Number=Sing',
#       'arc': 'obl',
#       'lemma': 'país',
#       'modifiers': [{'NE': '',
#         'POS_coarse': 'SCONJ',
#         'POS_fine': 'SCONJ___',
#         'arc': 'mark',
#         'lemma': 'comer',
#         'modifiers': [],
#         'word': 'como'},
#        {'NE': '',
#         'POS_coarse': 'ADJ',
#         'POS_fine': 'ADJ__Gender=Masc|Number=Sing',
#         'arc': 'amod',
#         'lemma': 'único',
#         'modifiers': [],
#         'word': 'único'},
#        {'NE': 'LOC',
#         'POS_coarse': 'PROPN',
#         'POS_fine': 'PROPN___',
#         'arc': 'nmod',
#         'lemma': 'Eurozona',
#         'modifiers': [{'NE': '',
#           'POS_coarse': 'ADP',
#           'POS_fine': 'ADP__AdpType=Prep',
#           'arc': 'case',
#           'lemma': 'de',
#           'modifiers': [],
#           'word': 'de'},
#          {'NE': '',
#           'POS_coarse': 'DET',
#           'POS_fine': 'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#           'arc': 'det',
#           'lemma': 'lo',
#           'modifiers': [],
#           'word': 'la'}],
#         'word': 'Eurozona'},
#        {'NE': '',
#         'POS_coarse': 'VERB',
#         'POS_fine': 'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#         'arc': 'acl',
#         'lemma': 'suspender',
#         'modifiers': [{'NE': '',
#           'POS_coarse': 'PRON',
#           'POS_fine': 'PRON__PronType=Rel',
#           'arc': 'nsubj',
#           'lemma': 'que',
#           'modifiers': [{'NE': 'ORG',
#             'POS_coarse': '',
#             'POS_fine': '',
#             'arc': '',
#             'lemma': '\n',
#             'modifiers': [],
#             'word': '\n'}],
#           'word': 'que'},
#          {'NE': '',
#           'POS_coarse': 'VERB',
#           'POS_fine': 'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#           'arc': 'conj',
#           'lemma': 'seguir',
#           'modifiers': [{'NE': '',
#             'POS_coarse': 'CONJ',
#             'POS_fine': 'CCONJ___',
#             'arc': 'cc',
#             'lemma': 'y',
#             'modifiers': [],
#             'word': 'y'},
#            {'NE': '',
#             'POS_coarse': 'NOUN',
#             'POS_fine': 'NOUN__Gender=Fem|Number=Sing',
#             'arc': 'obl',
#             'lemma': 'vigilancia',
#             'modifiers': [{'NE': '',
#               'POS_coarse': 'ADP',
#               'POS_fine': 'ADP__AdpType=Prep',
#               'arc': 'case',
#               'lemma': 'bajar',
#               'modifiers': [],
#               'word': 'bajo'}],
#             'word': 'vigilancia'}],
#           'word': 'sigue'}],
#         'word': 'suspende'}],
#       'word': 'país'}],
#     'word': 'quedará'},
#    {'NE': '',
#     'POS_coarse': 'PUNCT',
#     'POS_fine': 'PUNCT__PunctType=Peri',
#     'arc': 'punct',
#     'lemma': '.',
#     'modifiers': [],
#     'word': '.'}],
#   'word': 'aprobará'},
#  {'NE': '',
#   'POS_coarse': 'VERB',
#   'POS_fine': 'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#   'arc': 'ROOT',
#   'lemma': 'saltar',
#   'modifiers': [{'NE': 'MISC',
#     'POS_coarse': 'PROPN',
#     'POS_fine': 'PROPN___',
#     'arc': 'nsubj',
#     'lemma': 'El Gobierno',
#     'modifiers': [],
#     'word': 'El Gobierno'},
#    {'NE': '',
#     'POS_coarse': 'PRON',
#     'POS_fine': 'PRON__Person=3',
#     'arc': 'obj',
#     'lemma': 'se',
#     'modifiers': [],
#     'word': 'se'},
#    {'NE': '',
#     'POS_coarse': 'ADV',
#     'POS_fine': 'ADV___',
#     'arc': 'advmod',
#     'lemma': 'finalmente',
#     'modifiers': [],
#     'word': 'finalmente'},
#    {'NE': '',
#     'POS_coarse': 'NOUN',
#     'POS_fine': 'NOUN__Gender=Masc|Number=Sing',
#     'arc': 'obj',
#     'lemma': 'requerir',
#     'modifiers': [{'NE': '',
#       'POS_coarse': 'DET',
#       'POS_fine': 'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#       'arc': 'det',
#       'lemma': 'el',
#       'modifiers': [],
#       'word': 'el'},
#      {'NE': '',
#       'POS_coarse': 'NOUN',
#       'POS_fine': 'NOUN__Gender=Masc|Number=Sing',
#       'arc': 'nmod',
#       'lemma': 'saneamiento',
#       'modifiers': [{'NE': '',
#         'POS_coarse': 'ADP',
#         'POS_fine': 'ADP__AdpType=Prep',
#         'arc': 'case',
#         'lemma': 'de',
#         'modifiers': [],
#         'word': 'de'},
#        {'NE': '',
#         'POS_coarse': 'ADJ',
#         'POS_fine': 'ADJ__Gender=Masc|Number=Sing',
#         'arc': 'amod',
#         'lemma': 'presupuestario',
#         'modifiers': [{'NE': 'ORG',
#           'POS_coarse': '',
#           'POS_fine': '',
#           'arc': '',
#           'lemma': '\n',
#           'modifiers': [],
#           'word': '\n'}],
#         'word': 'presupuestario'},
#        {'NE': 'MISC',
#         'POS_coarse': 'PROPN',
#         'POS_fine': 'PROPN___',
#         'arc': 'nmod',
#         'lemma': 'Tratado de Maastricht',
#         'modifiers': [{'NE': '',
#           'POS_coarse': 'ADP',
#           'POS_fine': 'ADP__AdpType=Preppron|Gender=Masc|Number=Sing',
#           'arc': 'case',
#           'lemma': 'del',
#           'modifiers': [],
#           'word': 'del'}],
#         'word': 'Tratado de Maastricht'}],
#       'word': 'saneamiento'}],
#     'word': 'requisito'},
#    {'NE': '',
#     'POS_coarse': 'VERB',
#     'POS_fine': 'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#     'arc': 'conj',
#     'lemma': 'obtener',
#     'modifiers': [{'NE': '',
#       'POS_coarse': 'CONJ',
#       'POS_fine': 'CCONJ___',
#       'arc': 'cc',
#       'lemma': 'y',
#       'modifiers': [],
#       'word': 'y'},
#      {'NE': '',
#       'POS_coarse': 'ADV',
#       'POS_fine': 'ADV___',
#       'arc': 'advmod',
#       'lemma': 'asir',
#       'modifiers': [],
#       'word': 'así'},
#      {'NE': '',
#       'POS_coarse': 'NOUN',
#       'POS_fine': 'NOUN__Number=Sing',
#       'arc': 'obj',
#       'lemma': 'margen',
#       'modifiers': [{'NE': '',
#         'POS_coarse': 'ADV',
#         'POS_fine': 'ADV___',
#         'arc': 'advmod',
#         'lemma': 'más',
#         'modifiers': [],
#         'word': 'más'},
#        {'NE': '',
#         'POS_coarse': 'NOUN',
#         'POS_fine': 'NOUN__Gender=Masc|Number=Sing',
#         'arc': 'nmod',
#         'lemma': 'gastar',
#         'modifiers': [{'NE': '',
#           'POS_coarse': 'ADP',
#           'POS_fine': 'ADP__AdpType=Prep',
#           'arc': 'case',
#           'lemma': 'de',
#           'modifiers': [],
#           'word': 'de'}],
#         'word': 'gasto'}],
#       'word': 'margen'},
#      {'NE': '',
#       'POS_coarse': 'NOUN',
#       'POS_fine': 'NOUN__AdvType=Tim',
#       'arc': 'obl',
#       'lemma': '2018',
#       'modifiers': [{'NE': '',
#         'POS_coarse': 'ADP',
#         'POS_fine': 'ADP__AdpType=Prep',
#         'arc': 'case',
#         'lemma': 'en',
#         'modifiers': [],
#         'word': 'en'}],
#       'word': '2018'}],
#     'word': 'obtiene'},
#    {'NE': '',
#     'POS_coarse': 'PUNCT',
#     'POS_fine': 'PUNCT__PunctType=Peri',
#     'arc': 'punct',
#     'lemma': '.',
#     'modifiers': [],
#     'word': '.'}],
#   'word': 'salta'}]

# %% [markdown]
# Pero también se puede dibujar el grafo con las dependencias:

# %%
from spacy import displacy
displacy.serve(doc, style='dep')
# Out:
#     Serving on port 5000...
#     Using the 'dep' visualizer
#
#
#     Shutting down server on port 5000.

# %% [markdown]
# O el de las entidades:

# %%
from spacy import displacy
displacy.serve(doc, style='ent')
# Out:
#     Serving on port 5000...
#     Using the 'ent' visualizer
#
#
#     Shutting down server on port 5000.
